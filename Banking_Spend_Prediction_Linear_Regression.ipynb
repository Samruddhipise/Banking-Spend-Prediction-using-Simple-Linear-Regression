# %% [markdown]
# # Banking Spend Prediction using Simple Linear Regression
# ## Aim: Predict customer credit card spending based on annual income

# %%
# Step 1: Import Required Libraries
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 4
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
# ----> 4 from sklearn.linear_model import LinearRegression
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
# Step 2: Prepare Dataset
X = np.array([30, 40, 50, 60, 70, 80, 90, 100, 110, 120])
y = np.array([10, 12, 15, 18, 20, 25, 28, 30, 35, 40])
X = X.reshape(-1, 1)

# %%
# Step 3 & 4: Create and Train Model
model = LinearRegression()
model.fit(X, y)

slope = model.coef_[0]
intercept = model.intercept_

print('Slope (Coefficient):', round(slope, 4))
print('Intercept:', round(intercept, 4))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Step 3 & 4: Create and Train Model
# ----> 2 model = LinearRegression()
#       3 model.fit(X, y)
#       5 slope = model.coef_[0]
#
# NameError: name 'LinearRegression' is not defined

# %%
# Step 5: Prediction
new_income = np.array([[95]])
predicted_spend = model.predict(new_income)

print('Predicted Annual Spend for Income 95k$: {:.2f}k$'.format(predicted_spend[0]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 # Step 5: Prediction
#       2 new_income = np.array([[95]])
# ----> 3 predicted_spend = model.predict(new_income)
#       5 print('Predicted Annual Spend for Income 95k$: {:.2f}k$'.format(predicted_spend[0]))
#
# NameError: name 'model' is not defined

# %%
# Step 6: Visualization
y_pred = model.predict(X)

plt.figure(figsize=(10,6))
plt.scatter(X, y, color='blue', s=80, label='Actual Data Points')
plt.plot(X, y_pred, color='red', linewidth=2, label='Regression Line')
plt.scatter(new_income, predicted_spend, color='green', s=120, marker='X', label='Predicted Point')

plt.title('Banking Spend Prediction using Simple Linear Regression')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Annual Spend (k$)')
plt.legend()
plt.grid(True)
plt.show()

print('Regression Equation: Annual Spend = ({:.4f} * Annual Income) + ({:.4f})'.format(slope, intercept))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Step 6: Visualization
# ----> 2 y_pred = model.predict(X)
#       4 plt.figure(figsize=(10,6))
#       5 plt.scatter(X, y, color='blue', s=80, label='Actual Data Points')
#
# NameError: name 'model' is not defined
